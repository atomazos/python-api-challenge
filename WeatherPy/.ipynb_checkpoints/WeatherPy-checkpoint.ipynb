# %% [markdown]
# # WeatherPy
#
# Three observable trends based on the WeatherPy data:
#
# 1. Unsurprisingly, the temperature becomes warmer approaching the equator (i.e., 0 degrees latitude). As we move   north from the equator, the temperature becomes less warm for this time of the year (i.e., beginning of autumn).
# 2. There is no significant relationship between latitude and humidity. Nonetheless, there seems to be a cluster of  cities in the northern hemispehere above 80% humidity.
# 3. There are no significant relationships between latitude and cloudiness or wind speed. However, a predominant number of cities in both hemispheres have wind speeds between 0 to 10 mph.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
# Installed pip install citipy on Terminal
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# %%
# Set up variables to store reponse data after API call

city_ow = []
lat = []
lon = []
temp = []
humid = []
clouds = []
wind = []

# Create the for loop:
print('------------------------------')
print('Records')
print('------------------------------')

# start the count at 1
number = 1

for city in cities:
    name = city
    print("Retreiving data for City #"+ str(number) + " of " + str((len(cities))) + " ... "  + name )
    query_url = f"{url}appid={api_key}&units={units}&q={city}"#use NY Times- Stu Retrieves - Activity
    print(query_url)
    print('--------------------------------------------------') 
    
    # Create query per normal course

    weather_response = requests.get(query_url).json()
    
    # loop through the response and append above variables to the list
    
    try:
        city_ow.append(weather_response["name"])
        lat.append(weather_response['coord']['lat'])
        lon.append(weather_response['coord']['lon'])
        temp.append(weather_response['main']['temp'])
        humid.append(weather_response['main']['humidity'])
        clouds.append(weather_response['clouds']['all'])
        wind.append(weather_response['wind']['speed'])
        number = number + 1
    
    except KeyError:
            print(f'Missing data {number} of {len(cities)}. | Skip {city}')
        
# Add an interval between queries to avert KeyError 403 from the API due to using 60 API calls per minute limit

    time.sleep(1)
# Out:
# ------------------------------
# Records
# ------------------------------
# Retreiving data for City #1 of 604 ... cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cidreira
# --------------------------------------------------
# City number 1 of 604. | Added cidreira
# Retreiving data for City #2 of 604 ... colares
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=colares
# --------------------------------------------------
# City number 2 of 604. | Added colares
# Retreiving data for City #3 of 604 ... banmo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=banmo
# --------------------------------------------------
# Missing data 3 of 604. | Skip banmo
# Retreiving data for City #3 of 604 ... cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cherskiy
# --------------------------------------------------
# City number 3 of 604. | Added cherskiy
# Retreiving data for City #4 of 604 ... orotukan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=orotukan
# --------------------------------------------------
# City number 4 of 604. | Added orotukan
# Retreiving data for City #5 of 604 ... punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=punta arenas
# --------------------------------------------------
# City number 5 of 604. | Added punta arenas
# Retreiving data for City #6 of 604 ... vardo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=vardo
# --------------------------------------------------
# City number 6 of 604. | Added vardo
# Retreiving data for City #7 of 604 ... rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=rikitea
# --------------------------------------------------
# City number 7 of 604. | Added rikitea
# Retreiving data for City #8 of 604 ... chuy
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=chuy
# --------------------------------------------------
# City number 8 of 604. | Added chuy
# Retreiving data for City #9 of 604 ... wewak
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=wewak
# --------------------------------------------------
# City number 9 of 604. | Added wewak
# Retreiving data for City #10 of 604 ... albany
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=albany
# --------------------------------------------------
# City number 10 of 604. | Added albany
# Retreiving data for City #11 of 604 ... nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=nouadhibou
# --------------------------------------------------
# City number 11 of 604. | Added nouadhibou
# Retreiving data for City #12 of 604 ... thompson
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=thompson
# --------------------------------------------------
# City number 12 of 604. | Added thompson
# Retreiving data for City #13 of 604 ... tecoanapa
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tecoanapa
# --------------------------------------------------
# City number 13 of 604. | Added tecoanapa
# Retreiving data for City #14 of 604 ... sistranda
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=sistranda
# --------------------------------------------------
# City number 14 of 604. | Added sistranda
# Retreiving data for City #15 of 604 ... tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tiksi
# --------------------------------------------------
# City number 15 of 604. | Added tiksi
# Retreiving data for City #16 of 604 ... carthage
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=carthage
# --------------------------------------------------
# City number 16 of 604. | Added carthage
# Retreiving data for City #17 of 604 ... moyale
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=moyale
# --------------------------------------------------
# City number 17 of 604. | Added moyale
# Retreiving data for City #18 of 604 ... airai
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=airai
# --------------------------------------------------
# City number 18 of 604. | Added airai
# Retreiving data for City #19 of 604 ... trofors
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=trofors
# --------------------------------------------------
# City number 19 of 604. | Added trofors
# Retreiving data for City #20 of 604 ... valparaiso
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=valparaiso
# --------------------------------------------------
# City number 20 of 604. | Added valparaiso
# Retreiving data for City #21 of 604 ... mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mys shmidta
# --------------------------------------------------
# Missing data 21 of 604. | Skip mys shmidta
# Retreiving data for City #21 of 604 ... ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ushuaia
# --------------------------------------------------
# City number 21 of 604. | Added ushuaia
# Retreiving data for City #22 of 604 ... horta
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=horta
# --------------------------------------------------
# City number 22 of 604. | Added horta
# Retreiving data for City #23 of 604 ... gat
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=gat
# --------------------------------------------------
# City number 23 of 604. | Added gat
# Retreiving data for City #24 of 604 ... jiuquan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=jiuquan
# --------------------------------------------------
# City number 24 of 604. | Added jiuquan
# Retreiving data for City #25 of 604 ... bukama
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bukama
# --------------------------------------------------
# City number 25 of 604. | Added bukama
# Retreiving data for City #26 of 604 ... new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=new norfolk
# --------------------------------------------------
# City number 26 of 604. | Added new norfolk
# Retreiving data for City #27 of 604 ... rawson
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=rawson
# --------------------------------------------------
# City number 27 of 604. | Added rawson
# Retreiving data for City #28 of 604 ... saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=saint-philippe
# --------------------------------------------------
# City number 28 of 604. | Added saint-philippe
# Retreiving data for City #29 of 604 ... provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=provideniya
# --------------------------------------------------
# City number 29 of 604. | Added provideniya
# Retreiving data for City #30 of 604 ... severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=severo-kurilsk
# --------------------------------------------------
# City number 30 of 604. | Added severo-kurilsk
# Retreiving data for City #31 of 604 ... saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=saskylakh
# --------------------------------------------------
# City number 31 of 604. | Added saskylakh
# Retreiving data for City #32 of 604 ... ormara
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ormara
# --------------------------------------------------
# City number 32 of 604. | Added ormara
# Retreiving data for City #33 of 604 ... clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=clyde river
# --------------------------------------------------
# City number 33 of 604. | Added clyde river
# Retreiving data for City #34 of 604 ... taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=taolanaro
# --------------------------------------------------
# Missing data 34 of 604. | Skip taolanaro
# Retreiving data for City #34 of 604 ... qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=qaanaaq
# --------------------------------------------------
# City number 34 of 604. | Added qaanaaq
# Retreiving data for City #35 of 604 ... cape town
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cape town
# --------------------------------------------------
# City number 35 of 604. | Added cape town
# Retreiving data for City #36 of 604 ... illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=illoqqortoormiut
# --------------------------------------------------
# Missing data 36 of 604. | Skip illoqqortoormiut
# Retreiving data for City #36 of 604 ... hilo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=hilo
# --------------------------------------------------
# City number 36 of 604. | Added hilo
# Retreiving data for City #37 of 604 ... shingu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=shingu
# --------------------------------------------------
# City number 37 of 604. | Added shingu
# Retreiving data for City #38 of 604 ... luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=luderitz
# --------------------------------------------------
# City number 38 of 604. | Added luderitz
# Retreiving data for City #39 of 604 ... vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=vestmannaeyjar
# --------------------------------------------------
# City number 39 of 604. | Added vestmannaeyjar
# Retreiving data for City #40 of 604 ... mataura
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mataura
# --------------------------------------------------
# City number 40 of 604. | Added mataura
# Retreiving data for City #41 of 604 ... cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cururupu
# --------------------------------------------------
# City number 41 of 604. | Added cururupu
# Retreiving data for City #42 of 604 ... victoria
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=victoria
# --------------------------------------------------
# City number 42 of 604. | Added victoria
# Retreiving data for City #43 of 604 ... tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tuktoyaktuk
# --------------------------------------------------
# City number 43 of 604. | Added tuktoyaktuk
# Retreiving data for City #44 of 604 ... fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=fortuna
# --------------------------------------------------
# City number 44 of 604. | Added fortuna
# Retreiving data for City #45 of 604 ... sorland
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=sorland
# --------------------------------------------------
# City number 45 of 604. | Added sorland
# Retreiving data for City #46 of 604 ... bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bredasdorp
# --------------------------------------------------
# City number 46 of 604. | Added bredasdorp
# Retreiving data for City #47 of 604 ... hobart
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=hobart
# --------------------------------------------------
# City number 47 of 604. | Added hobart
# Retreiving data for City #48 of 604 ... hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=hermanus
# --------------------------------------------------
# City number 48 of 604. | Added hermanus
# Retreiving data for City #49 of 604 ... salalah
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=salalah
# --------------------------------------------------
# City number 49 of 604. | Added salalah
# Retreiving data for City #50 of 604 ... hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=hambantota
# --------------------------------------------------
# City number 50 of 604. | Added hambantota
# Retreiving data for City #51 of 604 ... port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=port alfred
# --------------------------------------------------
# City number 51 of 604. | Added port alfred
# Retreiving data for City #52 of 604 ... tokur
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tokur
# --------------------------------------------------
# City number 52 of 604. | Added tokur
# Retreiving data for City #53 of 604 ... busselton
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=busselton
# --------------------------------------------------
# City number 53 of 604. | Added busselton
# Retreiving data for City #54 of 604 ... east london
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=east london
# --------------------------------------------------
# City number 54 of 604. | Added east london
# Retreiving data for City #55 of 604 ... vaini
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=vaini
# --------------------------------------------------
# City number 55 of 604. | Added vaini
# Retreiving data for City #56 of 604 ... samusu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=samusu
# --------------------------------------------------
# Missing data 56 of 604. | Skip samusu
# Retreiving data for City #56 of 604 ... tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tasiilaq
# --------------------------------------------------
# City number 56 of 604. | Added tasiilaq
# Retreiving data for City #57 of 604 ... mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mitsamiouli
# --------------------------------------------------
# City number 57 of 604. | Added mitsamiouli
# Retreiving data for City #58 of 604 ... katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=katsuura
# --------------------------------------------------
# City number 58 of 604. | Added katsuura
# Retreiving data for City #59 of 604 ... guangyuan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=guangyuan
# --------------------------------------------------
# City number 59 of 604. | Added guangyuan
# Retreiving data for City #60 of 604 ... faanui
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=faanui
# --------------------------------------------------
# City number 60 of 604. | Added faanui
# Retreiving data for City #61 of 604 ... aksarka
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=aksarka
# --------------------------------------------------
# City number 61 of 604. | Added aksarka
# Retreiving data for City #62 of 604 ... hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=hithadhoo
# --------------------------------------------------
# City number 62 of 604. | Added hithadhoo
# Retreiving data for City #63 of 604 ... coro
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=coro
# --------------------------------------------------
# City number 63 of 604. | Added coro
# Retreiving data for City #64 of 604 ... castro
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=castro
# --------------------------------------------------
# City number 64 of 604. | Added castro
# Retreiving data for City #65 of 604 ... nikel
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=nikel
# --------------------------------------------------
# City number 65 of 604. | Added nikel
# Retreiving data for City #66 of 604 ... saleaula
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=saleaula
# --------------------------------------------------
# Missing data 66 of 604. | Skip saleaula
# Retreiving data for City #66 of 604 ... jalu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=jalu
# --------------------------------------------------
# City number 66 of 604. | Added jalu
# Retreiving data for City #67 of 604 ... comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=comodoro rivadavia
# --------------------------------------------------
# City number 67 of 604. | Added comodoro rivadavia
# Retreiving data for City #68 of 604 ... northam
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=northam
# --------------------------------------------------
# City number 68 of 604. | Added northam
# Retreiving data for City #69 of 604 ... ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ilulissat
# --------------------------------------------------
# City number 69 of 604. | Added ilulissat
# Retreiving data for City #70 of 604 ... constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=constitucion
# --------------------------------------------------
# City number 70 of 604. | Added constitucion
# Retreiving data for City #71 of 604 ... ploemeur
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ploemeur
# --------------------------------------------------
# City number 71 of 604. | Added ploemeur
# Retreiving data for City #72 of 604 ... kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kavieng
# --------------------------------------------------
# City number 72 of 604. | Added kavieng
# Retreiving data for City #73 of 604 ... voskresenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=voskresenskoye
# --------------------------------------------------
# City number 73 of 604. | Added voskresenskoye
# Retreiving data for City #74 of 604 ... baboua
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=baboua
# --------------------------------------------------
# Missing data 74 of 604. | Skip baboua
# Retreiving data for City #74 of 604 ... souillac
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=souillac
# --------------------------------------------------
# City number 74 of 604. | Added souillac
# Retreiving data for City #75 of 604 ... codrington
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=codrington
# --------------------------------------------------
# City number 75 of 604. | Added codrington
# Retreiving data for City #76 of 604 ... kamwenge
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kamwenge
# --------------------------------------------------
# City number 76 of 604. | Added kamwenge
# Retreiving data for City #77 of 604 ... bluff
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bluff
# --------------------------------------------------
# City number 77 of 604. | Added bluff
# Retreiving data for City #78 of 604 ... seoul
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=seoul
# --------------------------------------------------
# City number 78 of 604. | Added seoul
# Retreiving data for City #79 of 604 ... umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=umzimvubu
# --------------------------------------------------
# Missing data 79 of 604. | Skip umzimvubu
# Retreiving data for City #79 of 604 ... avarua
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=avarua
# --------------------------------------------------
# City number 79 of 604. | Added avarua
# Retreiving data for City #80 of 604 ... muroto
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=muroto
# --------------------------------------------------
# City number 80 of 604. | Added muroto
# Retreiving data for City #81 of 604 ... kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kruisfontein
# --------------------------------------------------
# City number 81 of 604. | Added kruisfontein
# Retreiving data for City #82 of 604 ... jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=jamestown
# --------------------------------------------------
# City number 82 of 604. | Added jamestown
# Retreiving data for City #83 of 604 ... nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=nikolskoye
# --------------------------------------------------
# City number 83 of 604. | Added nikolskoye
# Retreiving data for City #84 of 604 ... khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=khatanga
# --------------------------------------------------
# City number 84 of 604. | Added khatanga
# Retreiving data for City #85 of 604 ... hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=hobyo
# --------------------------------------------------
# City number 85 of 604. | Added hobyo
# Retreiving data for City #86 of 604 ... asau
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=asau
# --------------------------------------------------
# Missing data 86 of 604. | Skip asau
# Retreiving data for City #86 of 604 ... newport
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=newport
# --------------------------------------------------
# City number 86 of 604. | Added newport
# Retreiving data for City #87 of 604 ... praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=praia da vitoria
# --------------------------------------------------
# City number 87 of 604. | Added praia da vitoria
# Retreiving data for City #88 of 604 ... arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=arraial do cabo
# --------------------------------------------------
# City number 88 of 604. | Added arraial do cabo
# Retreiving data for City #89 of 604 ... humboldt
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=humboldt
# --------------------------------------------------
# City number 89 of 604. | Added humboldt
# Retreiving data for City #90 of 604 ... mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mahebourg
# --------------------------------------------------
# City number 90 of 604. | Added mahebourg
# Retreiving data for City #91 of 604 ... san joaquin
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=san joaquin
# --------------------------------------------------
# City number 91 of 604. | Added san joaquin
# Retreiving data for City #92 of 604 ... merauke
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=merauke
# --------------------------------------------------
# City number 92 of 604. | Added merauke
# Retreiving data for City #93 of 604 ... lisala
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=lisala
# --------------------------------------------------
# City number 93 of 604. | Added lisala
# Retreiving data for City #94 of 604 ... pacifica
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=pacifica
# --------------------------------------------------
# City number 94 of 604. | Added pacifica
# Retreiving data for City #95 of 604 ... bialogard
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bialogard
# --------------------------------------------------
# City number 95 of 604. | Added bialogard
# Retreiving data for City #96 of 604 ... adre
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=adre
# --------------------------------------------------
# City number 96 of 604. | Added adre
# Retreiving data for City #97 of 604 ... cabiraoan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cabiraoan
# --------------------------------------------------
# City number 97 of 604. | Added cabiraoan
# Retreiving data for City #98 of 604 ... brownsville
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=brownsville
# --------------------------------------------------
# City number 98 of 604. | Added brownsville
# Retreiving data for City #99 of 604 ... honningsvag
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=honningsvag
# --------------------------------------------------
# City number 99 of 604. | Added honningsvag
# Retreiving data for City #100 of 604 ... yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=yerofey pavlovich
# --------------------------------------------------
# City number 100 of 604. | Added yerofey pavlovich
# Retreiving data for City #101 of 604 ... shaunavon
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=shaunavon
# --------------------------------------------------
# City number 101 of 604. | Added shaunavon
# Retreiving data for City #102 of 604 ... berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=berlevag
# --------------------------------------------------
# City number 102 of 604. | Added berlevag
# Retreiving data for City #103 of 604 ... nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=nizhneyansk
# --------------------------------------------------
# Missing data 103 of 604. | Skip nizhneyansk
# Retreiving data for City #103 of 604 ... dikson
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=dikson
# --------------------------------------------------
# City number 103 of 604. | Added dikson
# Retreiving data for City #104 of 604 ... srandakan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=srandakan
# --------------------------------------------------
# City number 104 of 604. | Added srandakan
# Retreiving data for City #105 of 604 ... christchurch
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=christchurch
# --------------------------------------------------
# City number 105 of 604. | Added christchurch
# Retreiving data for City #106 of 604 ... san jeronimo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=san jeronimo
# --------------------------------------------------
# City number 106 of 604. | Added san jeronimo
# Retreiving data for City #107 of 604 ... boende
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=boende
# --------------------------------------------------
# City number 107 of 604. | Added boende
# Retreiving data for City #108 of 604 ... broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=broken hill
# --------------------------------------------------
# City number 108 of 604. | Added broken hill
# Retreiving data for City #109 of 604 ... bethel
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bethel
# --------------------------------------------------
# City number 109 of 604. | Added bethel
# Retreiving data for City #110 of 604 ... guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=guerrero negro
# --------------------------------------------------
# City number 110 of 604. | Added guerrero negro
# Retreiving data for City #111 of 604 ... georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=georgetown
# --------------------------------------------------
# City number 111 of 604. | Added georgetown
# Retreiving data for City #112 of 604 ... mendi
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mendi
# --------------------------------------------------
# City number 112 of 604. | Added mendi
# Retreiving data for City #113 of 604 ... havelock
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=havelock
# --------------------------------------------------
# City number 113 of 604. | Added havelock
# Retreiving data for City #114 of 604 ... yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=yellowknife
# --------------------------------------------------
# City number 114 of 604. | Added yellowknife
# Retreiving data for City #115 of 604 ... tyristrand
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tyristrand
# --------------------------------------------------
# City number 115 of 604. | Added tyristrand
# Retreiving data for City #116 of 604 ... enshi
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=enshi
# --------------------------------------------------
# City number 116 of 604. | Added enshi
# Retreiving data for City #117 of 604 ... ampanihy
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ampanihy
# --------------------------------------------------
# City number 117 of 604. | Added ampanihy
# Retreiving data for City #118 of 604 ... labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=labuhan
# --------------------------------------------------
# City number 118 of 604. | Added labuhan
# Retreiving data for City #119 of 604 ... tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tsihombe
# --------------------------------------------------
# Missing data 119 of 604. | Skip tsihombe
# Retreiving data for City #119 of 604 ... zharkent
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=zharkent
# --------------------------------------------------
# City number 119 of 604. | Added zharkent
# Retreiving data for City #120 of 604 ... riviere-au-renard
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=riviere-au-renard
# --------------------------------------------------
# City number 120 of 604. | Added riviere-au-renard
# Retreiving data for City #121 of 604 ... garden city
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=garden city
# --------------------------------------------------
# City number 121 of 604. | Added garden city
# Retreiving data for City #122 of 604 ... gorontalo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=gorontalo
# --------------------------------------------------
# City number 122 of 604. | Added gorontalo
# Retreiving data for City #123 of 604 ... glenwood springs
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=glenwood springs
# --------------------------------------------------
# City number 123 of 604. | Added glenwood springs
# Retreiving data for City #124 of 604 ... barabai
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=barabai
# --------------------------------------------------
# City number 124 of 604. | Added barabai
# Retreiving data for City #125 of 604 ... sur
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=sur
# --------------------------------------------------
# City number 125 of 604. | Added sur
# Retreiving data for City #126 of 604 ... villeneuve-sur-lot
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=villeneuve-sur-lot
# --------------------------------------------------
# City number 126 of 604. | Added villeneuve-sur-lot
# Retreiving data for City #127 of 604 ... bulawayo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bulawayo
# --------------------------------------------------
# City number 127 of 604. | Added bulawayo
# Retreiving data for City #128 of 604 ... cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cockburn town
# --------------------------------------------------
# City number 128 of 604. | Added cockburn town
# Retreiving data for City #129 of 604 ... te anau
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=te anau
# --------------------------------------------------
# City number 129 of 604. | Added te anau
# Retreiving data for City #130 of 604 ... palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=palabuhanratu
# --------------------------------------------------
# Missing data 130 of 604. | Skip palabuhanratu
# Retreiving data for City #130 of 604 ... pozo colorado
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=pozo colorado
# --------------------------------------------------
# City number 130 of 604. | Added pozo colorado
# Retreiving data for City #131 of 604 ... pisco
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=pisco
# --------------------------------------------------
# City number 131 of 604. | Added pisco
# Retreiving data for City #132 of 604 ... la rioja
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=la rioja
# --------------------------------------------------
# City number 132 of 604. | Added la rioja
# Retreiving data for City #133 of 604 ... kalakamati
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kalakamati
# --------------------------------------------------
# City number 133 of 604. | Added kalakamati
# Retreiving data for City #134 of 604 ... port blair
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=port blair
# --------------------------------------------------
# City number 134 of 604. | Added port blair
# Retreiving data for City #135 of 604 ... kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kapaa
# --------------------------------------------------
# City number 135 of 604. | Added kapaa
# Retreiving data for City #136 of 604 ... belushya guba
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=belushya guba
# --------------------------------------------------
# Missing data 136 of 604. | Skip belushya guba
# Retreiving data for City #136 of 604 ... portland
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=portland
# --------------------------------------------------
# City number 136 of 604. | Added portland
# Retreiving data for City #137 of 604 ... leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=leningradskiy
# --------------------------------------------------
# City number 137 of 604. | Added leningradskiy
# Retreiving data for City #138 of 604 ... ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ponta delgada
# --------------------------------------------------
# City number 138 of 604. | Added ponta delgada
# Retreiving data for City #139 of 604 ... cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cabo san lucas
# --------------------------------------------------
# City number 139 of 604. | Added cabo san lucas
# Retreiving data for City #140 of 604 ... marysville
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=marysville
# --------------------------------------------------
# City number 140 of 604. | Added marysville
# Retreiving data for City #141 of 604 ... kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kangaatsiaq
# --------------------------------------------------
# City number 141 of 604. | Added kangaatsiaq
# Retreiving data for City #142 of 604 ... torbay
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=torbay
# --------------------------------------------------
# City number 142 of 604. | Added torbay
# Retreiving data for City #143 of 604 ... eldorado
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=eldorado
# --------------------------------------------------
# City number 143 of 604. | Added eldorado
# Retreiving data for City #144 of 604 ... mayo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mayo
# --------------------------------------------------
# City number 144 of 604. | Added mayo
# Retreiving data for City #145 of 604 ... kawalu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kawalu
# --------------------------------------------------
# City number 145 of 604. | Added kawalu
# Retreiving data for City #146 of 604 ... banjar
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=banjar
# --------------------------------------------------
# City number 146 of 604. | Added banjar
# Retreiving data for City #147 of 604 ... hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=hualmay
# --------------------------------------------------
# City number 147 of 604. | Added hualmay
# Retreiving data for City #148 of 604 ... grootfontein
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=grootfontein
# --------------------------------------------------
# City number 148 of 604. | Added grootfontein
# Retreiving data for City #149 of 604 ... barrow
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=barrow
# --------------------------------------------------
# City number 149 of 604. | Added barrow
# Retreiving data for City #150 of 604 ... kutum
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kutum
# --------------------------------------------------
# City number 150 of 604. | Added kutum
# Retreiving data for City #151 of 604 ... saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=saint-augustin
# --------------------------------------------------
# City number 151 of 604. | Added saint-augustin
# Retreiving data for City #152 of 604 ... shaoyang
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=shaoyang
# --------------------------------------------------
# City number 152 of 604. | Added shaoyang
# Retreiving data for City #153 of 604 ... forbes
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=forbes
# --------------------------------------------------
# City number 153 of 604. | Added forbes
# Retreiving data for City #154 of 604 ... fillan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=fillan
# --------------------------------------------------
# City number 154 of 604. | Added fillan
# Retreiving data for City #155 of 604 ... san quintin
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=san quintin
# --------------------------------------------------
# City number 155 of 604. | Added san quintin
# Retreiving data for City #156 of 604 ... cochrane
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cochrane
# --------------------------------------------------
# City number 156 of 604. | Added cochrane
# Retreiving data for City #157 of 604 ... vostok
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=vostok
# --------------------------------------------------
# City number 157 of 604. | Added vostok
# Retreiving data for City #158 of 604 ... mercedes
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mercedes
# --------------------------------------------------
# City number 158 of 604. | Added mercedes
# Retreiving data for City #159 of 604 ... cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cayenne
# --------------------------------------------------
# City number 159 of 604. | Added cayenne
# Retreiving data for City #160 of 604 ... geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=geraldton
# --------------------------------------------------
# City number 160 of 604. | Added geraldton
# Retreiving data for City #161 of 604 ... carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=carnarvon
# --------------------------------------------------
# City number 161 of 604. | Added carnarvon
# Retreiving data for City #162 of 604 ... alyangula
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=alyangula
# --------------------------------------------------
# City number 162 of 604. | Added alyangula
# Retreiving data for City #163 of 604 ... nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=nanortalik
# --------------------------------------------------
# City number 163 of 604. | Added nanortalik
# Retreiving data for City #164 of 604 ... esmeralda
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=esmeralda
# --------------------------------------------------
# City number 164 of 604. | Added esmeralda
# Retreiving data for City #165 of 604 ... saint george
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=saint george
# --------------------------------------------------
# City number 165 of 604. | Added saint george
# Retreiving data for City #166 of 604 ... san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=san patricio
# --------------------------------------------------
# City number 166 of 604. | Added san patricio
# Retreiving data for City #167 of 604 ... mocambique
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mocambique
# --------------------------------------------------
# Missing data 167 of 604. | Skip mocambique
# Retreiving data for City #167 of 604 ... lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=lompoc
# --------------------------------------------------
# City number 167 of 604. | Added lompoc
# Retreiving data for City #168 of 604 ... nyrob
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=nyrob
# --------------------------------------------------
# City number 168 of 604. | Added nyrob
# Retreiving data for City #169 of 604 ... heidelberg
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=heidelberg
# --------------------------------------------------
# City number 169 of 604. | Added heidelberg
# Retreiving data for City #170 of 604 ... fuyang
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=fuyang
# --------------------------------------------------
# City number 170 of 604. | Added fuyang
# Retreiving data for City #171 of 604 ... bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bambous virieux
# --------------------------------------------------
# City number 171 of 604. | Added bambous virieux
# Retreiving data for City #172 of 604 ... ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ribeira grande
# --------------------------------------------------
# City number 172 of 604. | Added ribeira grande
# Retreiving data for City #173 of 604 ... marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=marsh harbour
# --------------------------------------------------
# City number 173 of 604. | Added marsh harbour
# Retreiving data for City #174 of 604 ... anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=anadyr
# --------------------------------------------------
# City number 174 of 604. | Added anadyr
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=qostanay
# --------------------------------------------------
# City number 492 of 604. | Added qostanay
# Retreiving data for City #493 of 604 ... kaoma
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kaoma
# --------------------------------------------------
# City number 493 of 604. | Added kaoma
# Retreiving data for City #494 of 604 ... mariental
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mariental
# --------------------------------------------------
# City number 494 of 604. | Added mariental
# Retreiving data for City #495 of 604 ... manzil salim
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=manzil salim
# --------------------------------------------------
# City number 495 of 604. | Added manzil salim
# Retreiving data for City #496 of 604 ... kirkuk
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kirkuk
# --------------------------------------------------
# City number 496 of 604. | Added kirkuk
# Retreiving data for City #497 of 604 ... valle de allende
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=valle de allende
# --------------------------------------------------
# City number 497 of 604. | Added valle de allende
# Retreiving data for City #498 of 604 ... hun
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=hun
# --------------------------------------------------
# City number 498 of 604. | Added hun
# Retreiving data for City #499 of 604 ... xadani
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=xadani
# --------------------------------------------------
# Missing data 499 of 604. | Skip xadani
# Retreiving data for City #499 of 604 ... spornoye
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=spornoye
# --------------------------------------------------
# City number 499 of 604. | Added spornoye
# Retreiving data for City #500 of 604 ... yichang
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=yichang
# --------------------------------------------------
# City number 500 of 604. | Added yichang
# Retreiving data for City #501 of 604 ... bac lieu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bac lieu
# --------------------------------------------------
# Missing data 501 of 604. | Skip bac lieu
# Retreiving data for City #501 of 604 ... alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=alice springs
# --------------------------------------------------
# City number 501 of 604. | Added alice springs
# Retreiving data for City #502 of 604 ... santiago del estero
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=santiago del estero
# --------------------------------------------------
# City number 502 of 604. | Added santiago del estero
# Retreiving data for City #503 of 604 ... broome
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=broome
# --------------------------------------------------
# City number 503 of 604. | Added broome
# Retreiving data for City #504 of 604 ... uhlove
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=uhlove
# --------------------------------------------------
# City number 504 of 604. | Added uhlove
# Retreiving data for City #505 of 604 ... belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=belmonte
# --------------------------------------------------
# City number 505 of 604. | Added belmonte
# Retreiving data for City #506 of 604 ... tacuarembo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tacuarembo
# --------------------------------------------------
# City number 506 of 604. | Added tacuarembo
# Retreiving data for City #507 of 604 ... juneau
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=juneau
# --------------------------------------------------
# City number 507 of 604. | Added juneau
# Retreiving data for City #508 of 604 ... police
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=police
# --------------------------------------------------
# City number 508 of 604. | Added police
# Retreiving data for City #509 of 604 ... saryshagan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=saryshagan
# --------------------------------------------------
# Missing data 509 of 604. | Skip saryshagan
# Retreiving data for City #509 of 604 ... soyo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=soyo
# --------------------------------------------------
# City number 509 of 604. | Added soyo
# Retreiving data for City #510 of 604 ... praya
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=praya
# --------------------------------------------------
# City number 510 of 604. | Added praya
# Retreiving data for City #511 of 604 ... ferkessedougou
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ferkessedougou
# --------------------------------------------------
# City number 511 of 604. | Added ferkessedougou
# Retreiving data for City #512 of 604 ... kamenskoye
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kamenskoye
# --------------------------------------------------
# Missing data 512 of 604. | Skip kamenskoye
# Retreiving data for City #512 of 604 ... ayagoz
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=ayagoz
# --------------------------------------------------
# City number 512 of 604. | Added ayagoz
# Retreiving data for City #513 of 604 ... campobasso
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=campobasso
# --------------------------------------------------
# City number 513 of 604. | Added campobasso
# Retreiving data for City #514 of 604 ... klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=klaksvik
# --------------------------------------------------
# City number 514 of 604. | Added klaksvik
# Retreiving data for City #515 of 604 ... samarai
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=samarai
# --------------------------------------------------
# City number 515 of 604. | Added samarai
# Retreiving data for City #516 of 604 ... monterey
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=monterey
# --------------------------------------------------
# City number 516 of 604. | Added monterey
# Retreiving data for City #517 of 604 ... nizwa
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=nizwa
# --------------------------------------------------
# City number 517 of 604. | Added nizwa
# Retreiving data for City #518 of 604 ... bargal
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bargal
# --------------------------------------------------
# Missing data 518 of 604. | Skip bargal
# Retreiving data for City #518 of 604 ... indianola
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=indianola
# --------------------------------------------------
# City number 518 of 604. | Added indianola
# Retreiving data for City #519 of 604 ... fasano
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=fasano
# --------------------------------------------------
# City number 519 of 604. | Added fasano
# Retreiving data for City #520 of 604 ... mananjary
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=mananjary
# --------------------------------------------------
# City number 520 of 604. | Added mananjary
# Retreiving data for City #521 of 604 ... tautira
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=tautira
# --------------------------------------------------
# City number 521 of 604. | Added tautira
# Retreiving data for City #522 of 604 ... solnechnyy
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=solnechnyy
# --------------------------------------------------
# City number 522 of 604. | Added solnechnyy
# Retreiving data for City #523 of 604 ... gotsu
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=gotsu
# --------------------------------------------------
# City number 523 of 604. | Added gotsu
# Retreiving data for City #524 of 604 ... skjervoy
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=skjervoy
# --------------------------------------------------
# City number 524 of 604. | Added skjervoy
# Retreiving data for City #525 of 604 ... kantunilkin
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kantunilkin
# --------------------------------------------------
# City number 525 of 604. | Added kantunilkin
# Retreiving data for City #526 of 604 ... zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=zhigansk
# --------------------------------------------------
# City number 526 of 604. | Added zhigansk
# Retreiving data for City #527 of 604 ... saint-georges
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=saint-georges
# --------------------------------------------------
# City number 527 of 604. | Added saint-georges
# Retreiving data for City #528 of 604 ... cordoba
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=cordoba
# --------------------------------------------------
# City number 528 of 604. | Added cordoba
# Retreiving data for City #529 of 604 ... konde
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=konde
# --------------------------------------------------
# Missing data 529 of 604. | Skip konde
# Retreiving data for City #529 of 604 ... carlsbad
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=carlsbad
# --------------------------------------------------
# City number 529 of 604. | Added carlsbad
# Retreiving data for City #530 of 604 ... miyako
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=miyako
# --------------------------------------------------
# City number 530 of 604. | Added miyako
# Retreiving data for City #531 of 604 ... puerto colombia
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=puerto colombia
# --------------------------------------------------
# City number 531 of 604. | Added puerto colombia
# Retreiving data for City #532 of 604 ... udachnyy
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=udachnyy
# --------------------------------------------------
# City number 532 of 604. | Added udachnyy
# Retreiving data for City #533 of 604 ... blois
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=blois
# --------------------------------------------------
# City number 533 of 604. | Added blois
# Retreiving data for City #534 of 604 ... bilma
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bilma
# --------------------------------------------------
# City number 534 of 604. | Added bilma
# Retreiving data for City #535 of 604 ... manitouwadge
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=manitouwadge
# --------------------------------------------------
# City number 535 of 604. | Added manitouwadge
# Retreiving data for City #536 of 604 ... simpang
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=simpang
# --------------------------------------------------
# City number 536 of 604. | Added simpang
# Retreiving data for City #537 of 604 ... oistins
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=oistins
# --------------------------------------------------
# City number 537 of 604. | Added oistins
# Retreiving data for City #538 of 604 ... sambava
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=sambava
# --------------------------------------------------
# City number 538 of 604. | Added sambava
# Retreiving data for City #539 of 604 ... kalabo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kalabo
# --------------------------------------------------
# City number 539 of 604. | Added kalabo
# Retreiving data for City #540 of 604 ... xinzhou
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=xinzhou
# --------------------------------------------------
# City number 540 of 604. | Added xinzhou
# Retreiving data for City #541 of 604 ... kolpashevo
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kolpashevo
# --------------------------------------------------
# City number 541 of 604. | Added kolpashevo
# Retreiving data for City #542 of 604 ... bay roberts
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=bay roberts
# --------------------------------------------------
# City number 542 of 604. | Added bay roberts
# Retreiving data for City #543 of 604 ... auki
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=auki
# --------------------------------------------------
# City number 543 of 604. | Added auki
# Retreiving data for City #544 of 604 ... camacupa
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=camacupa
# --------------------------------------------------
# City number 544 of 604. | Added camacupa
# Retreiving data for City #545 of 604 ... magadan
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=magadan
# --------------------------------------------------
# City number 545 of 604. | Added magadan
# Retreiving data for City #546 of 604 ... maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=maniitsoq
# --------------------------------------------------
# City number 546 of 604. | Added maniitsoq
# Retreiving data for City #547 of 604 ... surskoye
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=surskoye
# --------------------------------------------------
# City number 547 of 604. | Added surskoye
# Retreiving data for City #548 of 604 ... kaihua
# http://api.openweathermap.org/data/2.5/weather?appid=70175f1f3d4c73e1bd260df165206e8e&units=Imperial&q=kaihua
# --------------------------------------------------
# City number 548 of 604. | Added kaihua

# %%
#Create Pandas dataFrame

city_data_df = pd.DataFrame({'City': city_ow,
                            'Latitude': lat,
                            'Longitude': lon,
                            'Temperature': temp,
                            'Humidity': humid,
                            'Cloudiness': clouds,
                            'Wind Speed': wind})

#Save dataframe as csv
pd.DataFrame.to_csv(city_data_df,'city_data.csv')


city_data_df
# Out:
#              City  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0        Cidreira    -30.17     -50.22        61.28        69         100
# 1         Colares     38.80      -9.45        66.60        82          20
# 2        Cherskiy     68.75     161.30        31.40        95          96
# 3        Orotukan     62.26     151.67        27.44        54          24
# 4    Punta Arenas    -53.16     -70.91        58.26        41           0
# ..            ...       ...        ...          ...       ...         ...
# 543      Camacupa    -12.02      17.48        63.98        58          93
# 544       Magadan     59.56     150.80        37.88        50           0
# 545     Maniitsoq     65.42     -52.90        41.66        88           8
# 546      Surskoye     54.48      46.71        43.46        81         100
# 547        Kaihua     29.14     118.41        62.90        75           0
#
#      Wind Speed
# 0          8.52
# 1         16.11
# 2          6.20
# 3          2.21
# 4         20.80
# ..          ...
# 543        5.41
# 544        8.72
# 545       12.15
# 546        6.35
# 547        2.89
#
# [548 rows x 7 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Reset index to "City"
city_data_df = city_data_df.set_index('City')
city_data_df
# Out:
#               Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# City
# Cidreira        -30.17     -50.22        61.28        69         100
# Colares          38.80      -9.45        66.60        82          20
# Cherskiy         68.75     161.30        31.40        95          96
# Orotukan         62.26     151.67        27.44        54          24
# Punta Arenas    -53.16     -70.91        58.26        41           0
# ...                ...        ...          ...       ...         ...
# Camacupa        -12.02      17.48        63.98        58          93
# Magadan          59.56     150.80        37.88        50           0
# Maniitsoq        65.42     -52.90        41.66        88           8
# Surskoye         54.48      46.71        43.46        81         100
# Kaihua           29.14     118.41        62.90        75           0
#
#               Wind Speed
# City
# Cidreira            8.52
# Colares            16.11
# Cherskiy            6.20
# Orotukan            2.21
# Punta Arenas       20.80
# ...                  ...
# Camacupa            5.41
# Magadan             8.72
# Maniitsoq          12.15
# Surskoye            6.35
# Kaihua              2.89
#
# [548 rows x 6 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Try to emulate the homework output graphs in terms of style
x, y = city_data_df['Latitude'], city_data_df['Temperature']

with plt.style.context('seaborn'):
    plt.figure(figsize=(10,8))
    plt.grid()
    plt.scatter(x, y, label=None,color= 'DarkBlue', alpha=0.9)
    plt.xlabel('Latitude', fontsize=10)
    plt.ylabel('Tempretaure (F)',fontsize=10)
    plt.grid()
    plt.title('City Latitude v. Temperature (09-26-19)',fontsize=12)
    plt.xlim(-80, 100)
    plt.ylim (-10, 110) 
    plt.axvspan(0,0, color='red', alpha=0.7)
#save plot
plt.savefig("City Latitude v. Temperature (09-26-19).png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x, y = city_data_df['Latitude'], city_data_df['Humidity']

with plt.style.context('seaborn'):
    plt.figure(figsize=(10,8))
    plt.grid()
    plt.scatter(x, y, label=None,color= 'DarkBlue', alpha=0.9)
    plt.xlabel('Latitude', fontsize=10)
    plt.ylabel('Humidity',fontsize=10)
    plt.grid()
    plt.title('City Latitude v. Humidity (09-26-19)',fontsize=12)
    plt.xlim(-80, 100)
    plt.ylim (-10, 110) 
    plt.axvspan(0,0, color='red', alpha=0.7)

#save plot
plt.savefig("City Latitude v. Humidity (09-26-19).png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x, y = city_data_df['Latitude'], city_data_df['Cloudiness']

with plt.style.context('seaborn'):
    plt.figure(figsize=(10,8))
    plt.grid()
    plt.scatter(x, y, label=None,color= 'DarkBlue', alpha=0.9)
    plt.xlabel('Latitude', fontsize=10)
    plt.ylabel('Cloudiness',fontsize=10)
    plt.grid()
    plt.title('City Latitude v. Cloudiness (09-26-19)',fontsize=12)
    plt.xlim(-80, 100)
    plt.ylim (-10, 110) 
    plt.axvspan(0,0, color='red', alpha=0.7)

#save plot
plt.savefig("City Latitude v. Cloudiness (09-26-19).png")    
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x, y = city_data_df['Latitude'], city_data_df['Wind Speed']

with plt.style.context('seaborn'):
    plt.figure(figsize=(10,8))
    plt.grid()
    plt.scatter(x, y, label=None,color= 'DarkBlue', alpha=0.9)
    plt.xlabel('Latitude', fontsize=10)
    plt.ylabel('Wind Speed (mph)',fontsize=10)
    plt.grid()
    plt.title('City Latitude v. Wind Speed (09-26-19)',fontsize=12)
    plt.xlim(-80, 100)
    plt.ylim (-5, 35) 
    plt.axvspan(0,0, color='red', alpha=0.7)

#save plot    

plt.savefig("City Latitude v. Wind Speed (09-26-19).png")

plt.show()
